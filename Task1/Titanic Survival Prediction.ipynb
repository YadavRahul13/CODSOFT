# %% [markdown]
# IMPORTING IMPORTANT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# IMPORTING FILE

# %%
df=pd.read_csv("Titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.shape
# Out:
# (418, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# CHECKING MISSING VALUES

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# HANDLING MISSING VALUES

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Fare'].fillna(df['Fare'].mean(),inplace=True)

# %%
df.drop(columns='Cabin',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# CHECKING OUTLIERS AND SKWENESS

# %%
numcol=df.select_dtypes(["int64","float64"]).columns
catcol=df.select_dtypes(["object"]).columns

# %%
numcol
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
catcol
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Embarked'], dtype='object')

# %%
plt.figure(figsize=(12,12))
plt.suptitle("CHECKING SKWNESS")
pltn=1
for i in numcol:
 if pltn<=6:
   ax=plt.subplot(4,2,pltn)
   sns.distplot(df[i])
   plt.xlabel(i,fontsize=15)
   pltn=pltn+1
plt.tight_layout()

# %%
plt.figure(figsize=(12,12))
plt.suptitle("CHECKING OUTLIERS")
pltn=1
for i in numcol:
 if pltn<=6:
  ax=plt.subplot(4,2,pltn)
  sns.boxplot(df[i])
  plt.xlabel(i,fontsize=15)
  pltn=pltn+1
plt.tight_layout()

# %%
#Handling outliers using iqr (Age columns)
q25=df["Age"].quantile(0.25)
q75=df["Age"].quantile(0.75)
iqr=q75-q25
ul=q75+1.5*iqr
ll=q25-1.5*iqr
df['Age']=np.where(df['Age']>ul,ul,np.where(df['Age']<ll,ll,df['Age']))

# %%
#Handling outliers using iqr (SibSp columns)
q25=df["SibSp"].quantile(0.25)
q75=df["SibSp"].quantile(0.75)
iqr=q75-q25
ul=q75+1.5*iqr
ll=q25-1.5*iqr
df['SibSp']=np.where(df['SibSp']>ul,ul,np.where(df['SibSp']<ll,ll,df['SibSp']))

# %%
plt.figure(figsize=(12,12))
plt.suptitle("CHECKING OUTLIERS")
pltn=1
for i in numcol:
 if pltn<=6:
  ax=plt.subplot(4,2,pltn)
  sns.boxplot(df[i])
  plt.xlabel(i,fontsize=15)
  pltn=pltn+1
plt.tight_layout()

# %% [markdown]
# DATA VISUALIZATION

# %%
df['Survived'].value_counts()
# Out:
# 0    266
# 1    152
# Name: Survived, dtype: int64

# %%
sns.countplot(x='Survived',data=df)
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Sex',data=df)
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Survived',hue='Sex',data=df)
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Pclass',hue='Survived',data=df)
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='count'>

# %%
sns.distplot(df['Age'])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %%
plt.subplots(figsize=(15,4))
sns.distplot(df[df['Survived']==0]['Age'])
sns.distplot(df[df['Survived']==1]['Age'])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %%
plt.subplots(figsize=(15,4))
sns.distplot(df[df['Survived']==0]['Fare'])
sns.distplot(df[df['Survived']==1]['Fare'])
# Out:
# <AxesSubplot: xlabel='Fare', ylabel='Density'>

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# DROPPING IRRELEVANT COLUMNS

# %%
df.drop(['PassengerId'],axis=1,inplace=True)
df.drop(['Name'],axis=1,inplace=True)

# %% [markdown]
# CONVERTING CATEGORICAL COLUMNS INTO NUMERICAL

# %%
df['Sex']=df['Sex'].map({'male':1,'female':0})

# %%
df['Embarked']=df['Embarked'].map({'S':0,'C':1,'Q':2})

# %%
df
# Out:
#      Survived  Pclass  Sex       Age  SibSp  Parch              Ticket  \
# 0           0       3    1  34.50000    0.0      0              330911
# 1           1       3    0  47.00000    1.0      0              363272
# 2           0       2    1  54.87500    0.0      0              240276
# 3           0       3    1  27.00000    0.0      0              315154
# 4           1       3    0  22.00000    1.0      1             3101298
# ..        ...     ...  ...       ...    ...    ...                 ...
# 413         0       3    1  30.27259    0.0      0           A.5. 3236
# 414         1       1    0  39.00000    0.0      0            PC 17758
# 415         0       3    1  38.50000    0.0      0  SOTON/O.Q. 3101262
# 416         0       3    1  30.27259    0.0      0              359309
# 417         0       3    1  30.27259    1.0      1                2668
#
#          Fare  Embarked
# 0      7.8292         2
# 1      7.0000         0
# 2      9.6875         2
# 3      8.6625         0
# 4     12.2875         0
# ..        ...       ...
# 413    8.0500         0
# 414  108.9000         1
# 415    7.2500         0
# 416    8.0500         0
# 417   22.3583         1
#
# [418 rows x 9 columns]

# %% [markdown]
# SEPEARTING FEATURES AND TARGET

# %%
x=df.drop(['Survived','Ticket'],axis=1)

# %%
x.columns
# Out:
# Index(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'], dtype='object')

# %%
y=df['Survived']

# %% [markdown]
# SPLITTING TRAIN AND TEST DATA

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# MODEL TRAINING & EVALUATION

# %%
def mymodel(model):
 
 model.fit(xtrain,ytrain)
 ypred=model.predict(xtest)
 train=model.score(xtrain,ytrain)
 test=model.score(xtest,ytest)
 print(f"Training score:{train}\nTesting score:{test}")
 print(classification_report(ytest,ypred))
 return model

# %%
#KNeighborsClassifier
knn=mymodel(KNeighborsClassifier())
# Out:
# Training score:0.7945205479452054
# Testing score:0.6587301587301587
#               precision    recall  f1-score   support
#
#            0       0.74      0.76      0.75        85
#            1       0.47      0.44      0.46        41
#
#     accuracy                           0.66       126
#    macro avg       0.61      0.60      0.60       126
# weighted avg       0.65      0.66      0.66       126

# %%
#LogisticRegression
lr=mymodel(LogisticRegression())
# Out:
# Training score:1.0
# Testing score:1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#            1       1.00      1.00      1.00        41
#
#     accuracy                           1.00       126
#    macro avg       1.00      1.00      1.00       126
# weighted avg       1.00      1.00      1.00       126

# %%
#DecisionTreeClassifier
dtc=mymodel(DecisionTreeClassifier())
# Out:
# Training score:1.0
# Testing score:1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#            1       1.00      1.00      1.00        41
#
#     accuracy                           1.00       126
#    macro avg       1.00      1.00      1.00       126
# weighted avg       1.00      1.00      1.00       126

# %%
#RandomForestClassifier
rfr=mymodel(RandomForestClassifier())
# Out:
# Training score:1.0
# Testing score:1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#            1       1.00      1.00      1.00        41
#
#     accuracy                           1.00       126
#    macro avg       1.00      1.00      1.00       126
# weighted avg       1.00      1.00      1.00       126
